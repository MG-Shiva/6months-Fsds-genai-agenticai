# %%
i=32
i
# Out:
# 32

# %%
type(i)
# Out:
# int

# %%
type() # Missing Argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-2619444958.py in <cell line: 0>()
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
len(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-913095331.py in <cell line: 0>()
# ----> 1 len(i)
#
# TypeError: object of type 'int' has no len()

# %%
f=110.56
f
# Out:
# 110.56

# %%
float(f)
# Out:
# 110.56

# %%
type(f)
# Out:
# float

# %%
f1=1e0
f1
# Out:
# 1.0

# %%
f2=1e1
f2
# Out:
# 10.0

# %%
f3=1e2
f3
# Out:
# 100.0

# %%
f4=1e3
f4
# Out:
# 1000.0

# %%
f5=1E5
f5
# Out:
# 100000.0

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
a+b
a-b # First Output Missed
# Out:
# -10

# %%
a*b # First Output Missed
a/b
# Out:
# 0.5

# %%
print(a+b) # All outputs
print(a-b)
print(a*b)
print(a/b)
# Out:
# 30
# -10
# 200
# 0.5

# %%
n1=20
n2=30
add=n1+n2
print('The addition of two numbers', n1,'and', n2, 'is =', add)
# Out:
# The addition of two numbers 20 and 30 is = 50

# %%
num1=20     # Format function
num2=30     # 2 variables

add=num1+num2

print('The addition of {} and {} is = {}'. format(num1, num2, add) )
# Out:
# The addition of 20 and 30 is = 50

# %%
n1=10        # 3 variables
n2=20
n3=30

add=n1+n2+n3

print('The addition of {} and {} and {} is ={}'. format(n1, n2, n3, add))
# Out:
# The addition of 10 and 20 and 30 is =60

# %%
c = 1+2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c. real
# Out:
# 1.0

# %%
c. imag
# Out:
# 2.0

# %%
c= 5+10j
d= 10+25j

print(c+d)
print(c-d)
# Out:
# (15+35j)
# (-5-15j)

# %%
def team():
  print('Hello')

# %%
c=2+5J   # only j or J works for complex numbers
d=3+6J

print(c+d)
# Out:
# (5+11j)

# %%
b = true
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-47-1139399072.py in <cell line: 0>()
# ----> 1 b = true
#       2 b
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
d= False
d
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False +False
# Out:
# 0

# %%
False-True
# Out:
# -1

# %%
True-False
# Out:
# 1

# %%
True-True*False+1
# Out:
# 2

# %%
s='nit'
s
# Out:
# 'nit'
