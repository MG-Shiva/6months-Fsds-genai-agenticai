# %%
V=5 #Variable Declaration
V
# Out:
# 5

# %%
id(V) #Address Of Memory Location
# Out:
# 10757864

# %%
5=V
# Out:
#   File "/tmp/ipython-input-5-3891879836.py", line 1
#     5=V
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1v=9
# Out:
#   File "/tmp/ipython-input-6-4287692018.py", line 1
#     1v=9
#     ^
# SyntaxError: invalid decimal literal

# %%
V1=9
V1
# Out:
# 9

# %%
a2=10
A2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-3304223904.py in <cell line: 0>()
#       1 a2=10
# ----> 2 A2
#
# NameError: name 'A2' is not defined

# %%
a2
# Out:
# 10

# %%
V@=99
V@
# Out:
#   File "/tmp/ipython-input-15-1532269910.py", line 2
#     V@
#       ^
# SyntaxError: invalid syntax

# %%
V*=89
V*
# Out:
#   File "/tmp/ipython-input-16-423918971.py", line 2
#     V*
#       ^
# SyntaxError: invalid syntax

# %%
V_=7
V_
# Out:
# 7

# %%
if=67
# Out:
#   File "/tmp/ipython-input-18-2169825030.py", line 1
#     if=67
#       ^
# SyntaxError: invalid syntax

# %%
else =87 #Keyword Error #Reserved Words
# Out:
#   File "/tmp/ipython-input-19-675696378.py", line 1
#     else =87
#     ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword. kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword. kwlist)
# Out:
# 35

# %%
else=7
else
# Out:
#   File "/tmp/ipython-input-26-3323133436.py", line 1
#     else=7
#     ^
# SyntaxError: invalid syntax

# %%
Else=7 # Case Sensitive Reserved Variables
Else
# Out:
# 7

# %%
spam=1
spam
# Out:
# 1

# %%
prefix= 'py'
prefix ='thon'

# %%
prefix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-35-1266745909.py in <cell line: 0>()
# ----> 1 prefix
#
# NameError: name 'prefix' is not defined

# %%
'py'+ prefix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-34-3011634585.py in <cell line: 0>()
# ----> 1 'py'+ prefix
#
# NameError: name 'prefix' is not defined
