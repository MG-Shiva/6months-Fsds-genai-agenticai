# %%
1+1
# Out:
# 2

# %%
9+9
# Out:
# 18

# %%
7-8
# Out:
# -1

# %%
56*3
# Out:
# 168

# %%
67/7
# Out:
# 9.571428571428571

# %%
15/3 #Float Division
# Out:
# 5.0

# %%
15//3 #Int Division
# Out:
# 5

# %%
15/3
# Out:
# 5.0

# %%
3**2
# Out:
# 9

# %%
4**3
# Out:
# 64

# %%
_ #Previous Output
# Out:
# 64

# %%
_+10
# Out:
# 74

# %%
3+6*4-2-1
# Out:
# 25

# %%
3+6*4-(2-1)
# Out:
# 26

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.ceil(9.4)
# Out:
# 10

# %%
math.floor(9.4)
# Out:
# 9

# %%
Welcome To Nit
# Out:
#   File "/tmp/ipython-input-33-3686163566.py", line 1
#     Welcome To Nit
#             ^
# SyntaxError: invalid syntax

# %%
'welcome To Nit'
# Out:
# 'welcome To Nit'

# %%
"Hello"
# Out:
# 'Hello'

# %%
''' How Are You'''
# Out:
# ' How Are You'

# %%
"Welcome To
Nit"
# Out:
#   File "/tmp/ipython-input-29-2617967524.py", line 1
#     "Welcome To
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'welcome To
Nit'
# Out:
#   File "/tmp/ipython-input-30-4053644977.py", line 1
#     'welcome To
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome To
Nit'''
# Out:
# 'welcome To \nNit'

# %%
S= 'Hello'
S
# Out:
# 'Hello'

# %%
S[1] #Hello-01234
# Out:
# 'e'

# %%
S[0]
# Out:
# 'H'

# %%
S[3&4]
# Out:
# 'H'

# %%
S[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-42-2802656458.py in <cell line: 0>()
# ----> 1 S[10]
#
# IndexError: string index out of range
